# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np
 
# !pip install fuzzywuzzy
# !pip install python-Levenshtein
# Out:
# ...
#      |████████████████████████████████| 51kB 1.7MB/s
# ...
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.0-cp36-cp36m-linux_x86_64.whl size=144804 sha256=c4f3900a287370ae35e6cfba4f656f6458897df2e9809fa669a7d566a5bdb640
#   Stored in directory: /root/.cache/pip/wheels/de/c2/93/660fd5f7559049268ad2dc6d81c4e39e9e36518766eaf7e342
# Successfully built python-Levenshtein
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-158b971a-ff72-4eef-97ed-0f45f21f5320" name="files[]" multiple disabled />
#      <output id="result-158b971a-ff72-4eef-97ed-0f45f21f5320">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Mapped sku.xlsx to Mapped sku (1).xlsx
# ...

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
def checker(wrong_options,correct_options):
    names_array=[]
    ratio_array=[]    
    for wrong_option in wrong_options:
        if wrong_option in correct_options:
           names_array.append(wrong_option)
           ratio_array.append(100)
        else:   
            x=process.extractOne(wrong_option,correct_options,scorer=fuzz.token_set_ratio)
            names_array.append(x[0])
            ratio_array.append(x[1])
            return names_array,ratio_array

# %%
pd.set_option('display.max_rows', 2500)
pd.set_option('display.max_columns', 2500)
pd.set_option('display.width', 2000)

df=pd.read_excel("Mapped sku.xlsx")
strMatch = df["Company Dscription"].fillna(0)
strOptions =df["Distributor Item code"].fillna(0)
strMatch.tolist()
strOptions.tolist()
# Out:
# ['Abreza Dk 600x300',
#  'Abreza HL 600x300',
#  'Abreza LT 600x300',
#  'Aclin 600x600',
#  'Acton DC 600x600',
#  'Adoks Beige 600x600',
#  'Adoks Grey 600x600',
#  'Agates Bianco 600x300',
#  'Agates Nero 600x300',
#  'AGL Beige 600x300',
#  'AGL HL 600x300',
#  'AGL Lite 600x300',
#  'Ajmer Ivory 300x300',
#  'Albano White 800x800',
#  'Albito Lemon 600x600',
#  'Albito White 600x600',
#  'Albury HL 600x300',
#  'Algeria Beige 1200x600',
#  'Almendra SF 600x600',
#  'Almentos Floor 300x300',
#  'Almitos DK 600x300',
#  'Almitos HL 600x300',
#  'Almitos LT 600X300',
#  'Alpine Blue 300x300',
#  'Amaron Bright 600x300',
#  'Amatrix Beige 450x300',
#  'Amatrix Gris 450x300',
#  'Amazon Bright 600x300',
#  'Amazon DK 600x300',
#  'Amazon Floor 300x300',
#  'Amazon Gris 600x600',
#  'Amazon HL 600x300',
#  'Ambient Crema 300x300',
#  'Ambient Decor 600x300',
#  'Ambient DK 600x300',
#  'Ambient LT 600x300',
#  'Ambrosia Gold 1200x600',
#  'American Walnut 1200x300',
# ...

# %%
name_match,ratio_match=checker(strMatch,strOptions) 
name_match,ratio_match=checker(strMatch,strOptions)
df1 = pd.DataFrame()
df1["old_names"]=pd.Series(strMatch)
df1["correct_names"]=pd.Series(name_match)
df1["correct_ratio"]=pd.Series(ratio_match)
print(df1)
# Out:
#                                       old_names     correct_names  correct_ratio
# 0                 KKWD 300x600-06 PLAIN IVORY-P  DC Ivory 600x600           67.0
# 1      KFE 240X060-80 BM-RE T'COTA(Q size PL)-P               NaN            NaN
# 2      KFE 300X300-10 BM-RE COB STONE IV(PLU)-P               NaN            NaN
# 3        KFE 240X060-80 FRENCH BLACK (R size)-P               NaN            NaN
# 4          KFE 400X400-06 BM-REC GREY (PLUS) -P               NaN            NaN
# ...                                         ...               ...            ...
# 15817     VFJ 400X400-8 TREASURE GRIS REC DIG-C               NaN            NaN
# 15818    VFJ 400X400-8 TREASURE NOIR REC DIG -C               NaN            NaN
# 15819    VFJ 400X400-8 TREASURE OLIVE REC DIG-C               NaN            NaN
# 15820    VFJ 400X400-8 TREASURE UMBER REC DIG-C               NaN            NaN
# 15821         O6VM 600X600-4 SAVLAN SF PO REC-C               NaN            NaN
#
# ...
